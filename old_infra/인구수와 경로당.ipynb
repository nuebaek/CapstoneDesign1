# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
plt.rc('axes', unicode_minus=False)
plt.rc('font', family='Malgun Gothic')
# %matplotlib inline

# %%
from IPython.display import set_matplotlib_formats
# 폰트가 선명하게 보이기 위해
set_matplotlib_formats('retina')

# %%
df = pd.read_csv("./data/people_senior.csv", low_memory=False)

# %%
df
# Out:
#       행정동명   인구수  병원  경로당
# 0   중계2.3동  7399  36   10
# 1     상계1동  6973  24   27
# 2     공릉1동  6509  36   19
# 3   상계3.4동  6109  14   15
# 4     월계3동  6080  24   12
# 5     월계2동  5848  14   18
# 6     공릉2동  5325  16   24
# 7   상계6.7동  5031  90   10
# 8     상계5동  5005   9   11
# 9     하계1동  4470  13   11
# 10    월계1동  4209  24   17
# 11    중계4동  4007  21   14
# 12    상계9동  3441  13    4
# 13    상계2동  3354  32   13
# 14    하계2동  3229   9    7
# 15    상계8동  2884  21    3
# 16   상계10동  2693   5    5
# 17    중계본동  2523  21   17
# 18    중계1동  2373  15    9

# %%
fig, ax1 = plt.subplots(figsize=(20, 8))
plt.title("행정동 노인인구별 경로당수")

ax1.set_xlabel("행정동 노인인구")
ax1.set_ylabel("경로당수")
ax1.bar(df["행정동명"], df["인구수"], color="c", label="노인인구")
ax1.legend(loc=2)

ax2= ax1.twinx()
ax2.set_ylabel("경로당수")
ax2.plot(df["행정동명"], df["경로당"], color="m", linewidth=4.0, label="경로당수")
ax2.legend(loc=1)

plt.legend()
plt.grid()

plt.show()

# %%
df.corr()
# Out:
#           인구수        병원       경로당
# 인구수  1.000000  0.265989  0.545808
# 병원   0.265989  1.000000  0.057868
# 경로당  0.545808  0.057868  1.000000

# %%
# lmplot 시각화 (회귀선)
sns.lmplot(data = df, x = '인구수', y = '경로당') 
plt.title("노인인구수와 경로당의 상관관계")
# Out:
# Text(0.5, 1.0, '노인인구수와 경로당의 상관관계')

# %%
# outlier (상계 6.7동) 제거
df=df.drop(7)

# %%
df.corr()
# Out:
#           인구수        병원       경로당
# 인구수  1.000000  0.440337  0.557750
# 병원   0.440337  1.000000  0.330802
# 경로당  0.557750  0.330802  1.000000

# %%
fig, ax1 = plt.subplots(figsize=(20, 8))
plt.title("행정동 노인인구별 경로당수")

ax1.set_xlabel("행정동 노인인구")
ax1.set_ylabel("경로당수")
ax1.bar(df["행정동명"], df["인구수"], color="c", label="노인인구")
ax1.legend(loc=2)

ax2= ax1.twinx()
ax2.set_ylabel("경로당수")
ax2.plot(df["행정동명"], df["경로당"], color="m", linewidth=4.0, label="경로당수")
ax2.legend(loc=1)

plt.legend()
plt.grid()

plt.show()
